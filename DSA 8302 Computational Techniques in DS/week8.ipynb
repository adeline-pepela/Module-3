# %%
import pandas as pd

# GitHub raw URL
url = "https://raw.githubusercontent.com/adeline-pepela/Module-3/main/DSA%208302%20Computational%20Techniques%20in%20DS/week%208/dmu1.csv"


# Load dataset
df = pd.read_csv(url)

# Preview dataset
df.head()
# Out:
#        DMU  Employees  operating_cost  loans_processed  customer_satisfaction
# 0  Branch1         12           50000             1500                    4.5
# 1  Branch2         10           45000             1400                    4.6
# 2  Branch3          8           42000             1300                    4.4
# 3  Branch4         11           47000             1350                    4.2

# %%
from pyDEA.core.utils.dea_utils import run_dea_from_config
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pyDEA.core.utils.dea_utils import run_dea_from_config
#
# ImportError: cannot import name 'run_dea_from_config' from 'pyDEA.core.utils.dea_utils' (C:\Users\PC\anaconda3\Lib\site-packages\pyDEA\core\utils\dea_utils.py)

# %%
pip install pyDEA
# Out:
# ...
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/3.5 MB 245.8 kB/s eta 0:00:15
#       --------------------------------------- 0.1/3.5 MB 383.3 kB/s eta 0:00:09
#      - -------------------------------------- 0.1/3.5 MB 469.7 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/3.5 MB 379.3 kB/s eta 0:00:09
#      - -------------------------------------- 0.2/3.5 MB 477.7 kB/s eta 0:00:07
#      -- ------------------------------------- 0.2/3.5 MB 551.4 kB/s eta 0:00:06
#      --- ------------------------------------ 0.3/3.5 MB 630.9 kB/s eta 0:00:06
#      --- ------------------------------------ 0.3/3.5 MB 613.6 kB/s eta 0:00:06
#      ---- ----------------------------------- 0.4/3.5 MB 676.0 kB/s eta 0:00:05
# ...

# %%
dmu1=pd.read_csv('dmu1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dmu1=pd.read_csv('dmu1.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
# ...

# %%
dmu1

# %%
from

# %%
from pyDEA.core.utils.dea_utils import run_dea_from_config

# %%
{
    "orientation": "input",
    "returns_to_scale": "CRS",
    "input_categories":["employees", "Operating_cost","customer_satisfaction"],
    "output_categories":["loan_processed"]

}
# Out:
# {'orientation': 'input',
#  'returns_to_scale': 'CRS',
#  'input_categories': ['employees', 'Operating_cost', 'customer_satisfaction'],
#  'output_categories': ['loan_processed']}

# %%
run_dea_from_config(
    config_file= "dmu1.json",
    data_file="dmu1.csv",
    output_file="DMU_Results"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_dea_from_config(
#       2     config_file= "dmu1.json",
#       3     data_file="dmu1.csv",
#       4     output_file="DMU_Results"
#       5 )
#
# NameError: name 'run_dea_from_config' is not defined
